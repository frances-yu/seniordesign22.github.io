# %%
import pandas as pd
import county_library as CL
import county_stratification as CS

# %% [markdown]
# # Get Strata and 2018

# %%
# Make sure to write the proper path
train, test = CS.get_train_test(path='')

# %%
train[3].head(10)
# Out:
#     FIPS  Poverty Rate   Income  Unemployment Rate  Prescription Rate  \
# 0  12071          15.9  50713.0                5.2               65.4
# 1  12081          14.8  50728.0                5.1               77.3
# 2  12083          18.7  40053.0                6.5               89.8
# 3  12086          20.0  43687.0                5.8               32.0
# 4  12091          11.3  55391.0                4.5               87.5
# 5  12095          15.6  50593.0                5.0               46.0
# 6  12097          18.5  45127.0                5.8               56.3
# 7  12099          13.5  56638.0                5.1               59.9
# 8  12101          14.6  46080.0                5.9               85.0
# 9  12103          13.6  47591.0                5.0               83.6
#
#    Death Rate  Strata
# 0       12.25     4.0
# 1       34.40     4.0
# 2        4.95     4.0
# 3        5.01     4.0
# 4       20.13     4.0
# 5       12.11     4.0
# 6       10.19     4.0
# 7        9.77     4.0
# 8        8.44     4.0
# 9        6.74     4.0

# %% [markdown]
# # Write to Files

# %%
train[0].to_csv('strata1.csv')
train[1].to_csv('strata2.csv')
train[2].to_csv('strata3.csv')
train[3].to_csv('strata4.csv')
train[4].to_csv('strata5.csv')

test.to_csv('test_set.csv')
